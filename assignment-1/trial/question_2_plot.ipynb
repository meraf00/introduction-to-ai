# %%
from matplotlib import pyplot as plt
import pandas as pd

from collections import defaultdict
from Romania import road_map, h_longitude_latitude_distance

df = pd.read_csv('result.csv')
df.head()
# Out:
# {'Oradea': [('Zerind', 71), ('Sibiu', 151)], 'Zerind': [('Oradea', 71), ('Arad', 75)], 'Sibiu': [('Oradea', 151), ('Arad', 140), ('Rimnicu Vilcea', 80), ('Fagaras', 99)], 'Arad': [('Zerind', 75), ('Sibiu', 140), ('Timisoara', 118)], 'Timisoara': [('Arad', 118), ('Lugoj', 111)], 'Rimnicu Vilcea': [('Sibiu', 80), ('Pitesti', 97), ('Craiova', 146)], 'Fagaras': [('Sibiu', 99), ('Bucharest', 211)], 'Lugoj': [('Timisoara', 111), ('Mehadia', 70)], 'Bucharest': [('Fagaras', 211), ('Pitesti', 101), ('Giurgiu', 90), ('Urziceni', 85)], 'Pitesti': [('Rimnicu Vilcea', 97), ('Craiova', 138), ('Bucharest', 101)], 'Craiova': [('Rimnicu Vilcea', 146), ('Pitesti', 138), ('Drobeta', 120)], 'Mehadia': [('Lugoj', 70), ('Drobeta', 75)], 'Drobeta': [('Craiova', 120), ('Mehadia', 75)], 'Giurgiu': [('Bucharest', 90)], 'Urziceni': [('Bucharest', 85), ('Hirsova', 98), ('Vaslui', 142)], 'Hirsova': [('Urziceni', 98), ('Eforie', 86)], 'Eforie': [('Hirsova', 86)], 'Vaslui': [('Urziceni', 142), ('Iasi', 92)], 'Iasi': [('Vaslui', 92), ('Neamt', 87)], 'Neamt': [('Iasi', 87)]}
#    Algorithm              City One    City Two    Average Time
# 0  breadth_first_search   Vaslui      Sibiu                      0.000051  \
# 1  depth_first_search     Vaslui      Sibiu                      0.000022
# 2  uniform_cost_search    Vaslui      Sibiu                      0.000029
# 3  iterative_deepening    Vaslui      Sibiu                      0.000036
# 4  greedy_search          Vaslui      Sibiu                      0.000035
#
#    Path Length
# 0            5
# 1           11
# 2            6
# 3            5
# 4            5

# %%
sample_cities = []

#            bfs dfs ucs  id  gr  a*
algorithms = [[], [], [], [], [], []]


# averg
cities_heuristic = []

for i in range(0, len(df), 6):


    cities = (df.iloc[i][1], df.iloc[i][2])
    sample_cities.append(cities)

    actual_distance = h_longitude_latitude_distance(cities[0], cities[1])
    cities_heuristic.append(actual_distance)
    

    for j in range(6):
        algorithms[j].append(df.iloc[i + j][3])




algs = ['breadth_first_search', 'depth_first_search', 'uniform_cost_search', 'iterative_deepening', 'greedy_search', 'a_star_search']

for i in range(6):
    plt.plot(cities_heuristic, algorithms[i], label=algs[i])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
