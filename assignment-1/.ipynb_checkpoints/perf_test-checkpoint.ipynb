# %%
import test

# %%
perf = test.test_performance()

# %%
for alg, val in perf.items()
# Out:
# {<function search_algorithms.depth_first_search(graph, start_node, end_node)>: [{'start': 7,
#    'end': 4,
#    'node_count': 10,
#    'runtime': 1.0179999662796035e-05},
#   {'start': 7, 'end': 8, 'node_count': 10, 'runtime': 1.7700000171316788e-05},
#   {'start': 7, 'end': 5, 'node_count': 10, 'runtime': 2.6819999766303228e-05},
#   {'start': 7, 'end': 2, 'node_count': 10, 'runtime': 3.395999956410378e-05},
#   {'start': 4, 'end': 8, 'node_count': 10, 'runtime': 4.2019999818876384e-05},
#   {'start': 4, 'end': 5, 'node_count': 10, 'runtime': 6.12800009548664e-05},
#   {'start': 4, 'end': 2, 'node_count': 10, 'runtime': 7.750000077066943e-05},
#   {'start': 8, 'end': 5, 'node_count': 10, 'runtime': 0.00010362000175518915},
#   {'start': 8, 'end': 2, 'node_count': 10, 'runtime': 0.00011978000184171833},
#   {'start': 5, 'end': 2, 'node_count': 10, 'runtime': 0.00012958000297658145},
#   {'start': 8, 'end': 1, 'node_count': 10, 'runtime': 1.1439999070717022e-05},
# ...
